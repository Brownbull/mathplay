# %%
# Based on https://docs.sympy.org/latest/tutorial/preliminaries.html
import sympy
import os
from sympy import *
from sympy.geometry import *

def custom_latex_printer(exp,**options):
    from google.colab.output._publish import javascript
    url = "https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.3/latest.js?config=default"
    javascript(url=url)
    return sympy.printing.latex(exp,**options)

if 'HOME' in os.environ:
    if 'Windows' in os.environ['OS']:
        print('Windows detected')
    else:
        # Google Colab Latex printing setup
        init_printing(use_latex="mathjax",latex_printer=custom_latex_printer)

# """ DIVISION IMPORTANT NOTE
# In divisions of python numbers(integers) 
# use Rational function to get exact results
# >>> Rational(1,2)  # = 1/2 """
# EXACT result use evalf => sqrt(8).evalf(5) = 2.8284
# """ GRAPHVIZ ON SYMPY
# from sympy.printing.dot import dotprint
# from graphviz import Source
# dot = Source(dotprint(x**2))
# dot
# """
# srepr(function)
'''
======================
3D surface (color map)
======================

Demonstrates plotting a 3D surface colored with the coolwarm color map.
The surface is made opaque by using antialiased=False.

Also demonstrates using the LinearLocator and custom formatting for the
z axis tick labels.
'''

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

# %%
# Vector Fields
from sympy import symbols, cos, sin
from sympy.plotting import *

x, y = symbols('x y')
expr_x = (x**3) - 9*x
expr_y = (y**3) - 9*y

x_range = (x, 0, 20)
y_range = (y, 0, 20)

# p = plot3d(expr_x, expr_y, x_range, y_range);
p = plot_parametric(expr_x, expr_y, x_range)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\DevSoft\Anaconda3\lib\site-packages\sympy\plotting\experimental_lambdify.py in __call__(self, args, kwargs)
#     194             #The result can be sympy.Float. Hence wrap it with complex type.
# --> 195             result = complex(self.lambda_func(args))
#     196             if abs(result.imag) > 1e-7 * abs(result):
#
# C:\DevSoft\Anaconda3\lib\site-packages\sympy\core\expr.py in __complex__(self)
#     284         re, im = result.as_real_imag()
# --> 285         return complex(float(re), float(im))
#     286
#
# C:\DevSoft\Anaconda3\lib\site-packages\sympy\core\expr.py in __float__(self)
#     279             raise TypeError("can't convert complex to float")
# --> 280         raise TypeError("can't convert expression to float")
#     281
#
# TypeError: can't convert expression to float
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-1dd55f3d4e1f> in <module>
#      11
#      12 # p = plot3d(expr_x, expr_y, x_range, y_range);
# ---> 13 p = plot_parametric(expr_x, expr_y, x_range)
#
# C:\DevSoft\Anaconda3\lib\site-packages\sympy\plotting\plot.py in plot_parametric(*args, **kwargs)
#    1513     plots = Plot(*series, **kwargs)
#    1514     if show:
# -> 1515         plots.show()
#    1516     return plots
#    1517
#
# C:\DevSoft\Anaconda3\lib\site-packages\sympy\plotting\plot.py in show(self)
#     185             self._backend.close()
#     186         self._backend = self.backend(self)
# --> 187         self._backend.show()
#     188
#     189     def save(self, path):
#
# C:\DevSoft\Anaconda3\lib\site-packages\sympy\plotting\plot.py in show(self)
#    1070
#    1071     def show(self):
# -> 1072         self.process_series()
#    1073         #TODO after fixing https://github.com/ipython/ipython/issues/1255
#    1074         # you can uncomment the next line and remove the pyplot.show() call
#
# C:\DevSoft\Anaconda3\lib\site-packages\sympy\plotting\plot.py in process_series(self)
#     932             # Create the collections
#     933             if s.is_2Dline:
# --> 934                 collection = self.LineCollection(s.get_segments())
#     935                 self.ax.add_collection(collection)
#     936             elif s.is_contour:
#
# C:\DevSoft\Anaconda3\lib\site-packages\sympy\plotting\plot.py in get_segments(self)
#     666
#     667         f_start_x = f_x(self.start)
# --> 668         f_start_y = f_y(self.start)
#     669         start = [f_start_x, f_start_y]
#     670         f_end_x = f_x(self.end)
#
# C:\DevSoft\Anaconda3\lib\site-packages\sympy\plotting\experimental_lambdify.py in __call__(self, args, kwargs)
#     234                         ' problematic. We are trying a failback method'
#     235                         ' that may still work. Please report this as a bug.')
# --> 236                 if abs(result.imag) > 1e-7 * abs(result):
#     237                     return None
#     238                 else:
#
# AttributeError: 'Add' object has no attribute 'imag'
